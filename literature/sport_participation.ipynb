# %%
import pandas as pd

# %%
path = '/Users/zhaotangyao/Downloads/Capstone/Datasets/'
sportseg_df = pd.read_excel(path + 'Sports_Segmented_by_Generations.xlsx')
activity_df = pd.read_excel(path + 'Activity_Category_Segmented_by_Generation.xlsx')
nonpart_df = pd.read_excel(path + 'Participation_Interests_Among_Non-Participants.xlsx')

# %%
nonpart_df
# Out:
#        Participation Interests Among Non-Participants            Unnamed: 1  \
# 0                                      Interest Level                  6~12
# 1                                                   1               Camping
# 2                                                   2               Fishing
# 3                                                   3                Soccer
# 4                                                   4            Basketball
# 5                                                   5             Bicycling
# 6                                                   6          Martial Arts
# 7                                                   7  Swimming for Fitness
# 8                                                   8              Football
# 9                                                   9    Swimming on a Team
# 10                                                 10            Volleyball
# ...

# %%
activity_df
# Out:
#           Activity Category Segmented by Generations    Unnamed: 1  \
# 0                                                NaN  Gen Z(2000+)
# 1                                 Individual  Sports         0.458
# 2                                     Racquet Sports         0.187
# 3                                        Team Sports         0.571
# 4                                     Outdoor Sports         0.602
# 5                                      Winter Sports         0.133
# 6                                       Water Sports         0.149
# 7                                     Fitness Sports         0.508
# 8  Description: While age clearly affects how oft...           NaN
#
#                Unnamed: 2        Unnamed: 3          Unnamed: 4
# 0  Millennials(1980-1999)  Gen X(1965-1979)  Boomers(1945-1964)
# 1                   0.424             0.344               0.238
# 2                   0.185             0.113               0.063
# ...

# %%
sportseg_df
# Out:
#   Participation Rates Segmented by Generations    Unnamed: 1  \
# 0                                          NaN  Gen Z(2000+)
# 1                                     Inactive         0.176
# 2                              Low/Med Calorie         0.174
# 3                     Casual & Low/Med Calorie         0.201
# 4                        Active & High Calorie         0.185
# 5                    Active to a Healthy Level         0.263
#
#                Unnamed: 2        Unnamed: 3          Unnamed: 4
# 0  Millennials(1980-1999)  Gen X(1965-1979)  Boomers(1945-1964)
# 1                    0.24             0.281               0.333
# 2                   0.164             0.187               0.296
# 3                    0.13             0.091               0.043
# 4                   0.113             0.091               0.063
# 5                   0.354              0.35               0.265

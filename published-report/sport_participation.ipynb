# %%
import pandas as pd

# %%
path = '/Users/zhaotangyao/Desktop/ads-on-run/csv/'
nonpart_df = pd.read_csv(path + 'Participation_Interests_Among_Non-Participants.csv',sep = ',')
activity_df = pd.read_csv(path + 'Activity_Category_Segmented_by_Generation.csv',sep = ',')
activity_df.dropna(axis=0, how='all',inplace=True)
sportseg_df = pd.read_csv(path + 'Sports_Segmented_by_Generations.csv', sep = ',')
sportseg_df.dropna(axis=0, how='all',inplace=True)

# %%
nonpart_df
# Out:
#        Participation Interests Among Non-Participants            Unnamed: 1  \
# 0                                      Interest Level                  6~12
# 1                                                   1               Camping
# 2                                                   2               Fishing
# 3                                                   3                Soccer
# 4                                                   4            Basketball
# 5                                                   5             Bicycling
# 6                                                   6          Martial Arts
# 7                                                   7  Swimming for Fitness
# 8                                                   8              Football
# 9                                                   9    Swimming on a Team
# 10                                                 10            Volleyball
# ...

# %%
activity_df
# Out:
#           Activity Category Segmented by Generations    Unnamed: 1  \
# 0                                                NaN  Gen Z(2000+)
# 1                                 Individual  Sports        0.4580
# 2                                     Racquet Sports        0.1870
# 3                                        Team Sports        0.5710
# 4                                     Outdoor Sports        0.6020
# 5                                      Winter Sports        0.1330
# 6                                       Water Sports        0.1490
# 7                                     Fitness Sports        0.5080
# 8  Description: While age clearly affects how oft...           NaN
#
#                Unnamed: 2        Unnamed: 3          Unnamed: 4
# 0  Millennials(1980-1999)  Gen X(1965-1979)  Boomers(1945-1964)
# 1                  0.4240            0.3440              0.2380
# 2                  0.1850            0.1130              0.0630
# ...

# %%
sportseg_df
# Out:
#   Participation Rates Segmented by Generations    Unnamed: 1  \
# 0                                          NaN  Gen Z(2000+)
# 1                                     Inactive        0.1760
# 2                              Low/Med Calorie        0.1740
# 3                     Casual & Low/Med Calorie        0.2010
# 4                        Active & High Calorie        0.1850
# 5                    Active to a Healthy Level        0.2630
#
#                Unnamed: 2        Unnamed: 3          Unnamed: 4
# 0  Millennials(1980-1999)  Gen X(1965-1979)  Boomers(1945-1964)
# 1                  0.2400            0.2810              0.3330
# 2                  0.1640            0.1870              0.2960
# 3                  0.1300            0.0910              0.0430
# 4                  0.1130            0.0910              0.0630
# 5                  0.3540            0.3500              0.2650

# %%
import pandas as pd

# %% [markdown]
# # Get 3 dataframes

# %%
zip_wo = pd.read_csv('../cluster/zip_code_age_lg_wealth_osm_percentage.csv', index_col="Unnamed: 0")

# %%
male_age_data = pd.read_csv('../data-collect/male_age_data.csv', index_col="Unnamed: 0")
female_age_data = pd.read_csv('../data-collect/female_age_data.csv', index_col="Unnamed: 0")

# %%
#zip_wo
#male_age_data

# %%
zip_wo_d = zip_wo.drop([10020])

# %%
male_age_data_d = male_age_data.drop([10020])
female_age_data_d = male_age_data.drop([10020])

# %% [markdown]
# # Make the dataframe for filter

# %%
zip_wo_d_s2 = zip_wo_d

# %%
zip_wo_d_s2['age0_18'] = male_age_data_d['0'] + female_age_data_d['0']
for i in range(1, 19):
    column = str(i)
    zip_wo_d_s2['age0_18'] += male_age_data_d[column] + female_age_data_d[column]

# %%
zip_wo_d_s2['age19_35'] = male_age_data_d['19'] + female_age_data_d['19']
for i in range(20, 36):
    column = str(i)
    zip_wo_d_s2['age19_35'] += male_age_data_d[column] + female_age_data_d[column]

# %%
zip_wo_d_s2['age36_55'] = male_age_data_d['36'] + female_age_data_d['36']
for i in range(37, 56):
    column = str(i)
    zip_wo_d_s2['age36_55'] += male_age_data_d[column] + female_age_data_d[column]

# %%
zip_wo_d_s2['age56_102'] = male_age_data_d['56'] + female_age_data_d['56']
for i in range(57, 103):
    column = str(i)
    zip_wo_d_s2['age56_102'] += male_age_data_d[column] + female_age_data_d[column]

# %%
zip_wo_d_s2['low_income'] = zip_wo_d['1-25,000'] + zip_wo_d['25,000-50,000']
zip_wo_d_s2['medium_income'] = zip_wo_d['50,000-75,000'] + zip_wo_d['75,000-100,000']
zip_wo_d_s2['high_income'] = zip_wo_d['100,000-200,000'] + zip_wo_d['200,000-...']

# %%
zip_wo_d_s2['age0_18'] = zip_wo_d_s2['age0_18'] / zip_wo_d_s2['age0_18'].sum()
zip_wo_d_s2['age19_35'] = zip_wo_d_s2['age19_35'] / zip_wo_d_s2['age19_35'].sum()
zip_wo_d_s2['age36_55'] = zip_wo_d_s2['age36_55'] / zip_wo_d_s2['age36_55'].sum()
zip_wo_d_s2['age56_102'] = zip_wo_d_s2['age56_102'] / zip_wo_d_s2['age56_102'].sum()


zip_wo_d_s2['shoes'] = zip_wo_d['shoes_count'] / zip_wo_d['shoes_count'].sum()
zip_wo_d_s2['restaurant'] = zip_wo_d['restaurant_count'] / zip_wo_d['restaurant_count'].sum()
zip_wo_d_s2['gym'] = zip_wo_d['gym_count'] / zip_wo_d['gym_count'].sum()
zip_wo_d_s2['clothes'] = zip_wo_d['clothes_count'] / zip_wo_d['clothes_count'].sum()
zip_wo_d_s2['clinic'] = zip_wo_d['clinic_count'] / zip_wo_d['clinic_count'].sum()

# %%
df = zip_wo_d_s2[['age0_18', 'age19_35', 'age36_55', 'age56_102', 'low_income', 'medium_income', 'high_income', 'shoes', 'restaurant', 'gym', 'clothes', 'clinic']]
#df

# %%
df.to_csv('csv_for_filtering.csv')

# %% [markdown]
# # Function for ranking zipcode according to selected features

# %%
zip_wo = pd.read_csv('csv_for_filtering.csv', index_col = 'Unnamed: 0')

# %%
zip_wo
# Out:
#         age0_18  age19_35  age36_55  age56_102  low_income  medium_income  \
# 10026  0.013804  0.011914  0.014681   0.009591    0.631522       0.215217
# 10027  0.022778  0.025765  0.020243   0.016877    0.675754       0.191203
# 10030  0.012659  0.009066  0.010411   0.007950    0.758146       0.181028
# 10037  0.006475  0.004955  0.005668   0.006625    0.634349       0.269621
# 10039  0.012425  0.007723  0.008699   0.006409    0.754050       0.184094
# 10001  0.003967  0.009342  0.009752   0.008290    0.432565       0.228512
# 10011  0.009205  0.020197  0.028669   0.022621    0.289109       0.232013
# 10018  0.000680  0.003257  0.002795   0.001465    0.389490       0.222566
# 10019  0.006768  0.021135  0.019369   0.018234    0.349698       0.239437
# 10036  0.003495  0.013872  0.013686   0.010648    0.409115       0.242895
# 10029  0.034877  0.028215  0.024494   0.023482    0.744711       0.181382
# 10035  0.015587  0.012755  0.014250   0.011505    0.735371       0.180754
# 10010  0.005219  0.016332  0.011460   0.011917    0.290618       0.258581
# 10016  0.007232  0.029636  0.018903   0.018822    0.300648       0.280604
# 10017  0.002017  0.007716  0.006045   0.007293    0.268730       0.229642
# 10022  0.005323  0.009907  0.011417   0.020852    0.247158       0.224419
# 10012  0.004205  0.012630  0.009378   0.010036    0.336703       0.245723
# 10013  0.007975  0.011254  0.012757   0.011873    0.437376       0.179589
# 10014  0.005041  0.014227  0.015098   0.013846    0.268446       0.239142
# 10004  0.000795  0.001897  0.001421   0.000640    0.240964       0.196787
# 10005  0.000758  0.005908  0.002341   0.000456    0.243506       0.254870
# 10006  0.000312  0.002554  0.001038   0.000300    0.255144       0.255144
# 10007  0.002240  0.003781  0.004463   0.001297    0.216216       0.135135
# 10038  0.004948  0.010508  0.006218   0.007229    0.445536       0.227682
# 10280  0.002389  0.003045  0.003897   0.002390    0.211494       0.202299
# 10002  0.027028  0.028133  0.030959   0.038129    0.709423       0.170873
# 10003  0.009639  0.031170  0.020393   0.019503    0.310815       0.255574
# 10009  0.014922  0.028192  0.022564   0.022189    0.504005       0.282112
# 10021  0.011125  0.013576  0.014351   0.022413    0.268817       0.236146
# 10028  0.012500  0.014383  0.016168   0.021408    0.282953       0.259760
# ...         ...       ...       ...        ...         ...            ...
# 10075  0.007010  0.007455  0.009050   0.013030    0.270963       0.255024
# 10128  0.017318  0.021527  0.021905   0.024727    0.318209       0.259403
# 10023  0.015835  0.018763  0.024163   0.030319    0.287683       0.208798
# 10024  0.018473  0.015861  0.024405   0.031115    0.314469       0.207395
# 10025  0.026946  0.032586  0.036152   0.042912    0.453359       0.224861
# 10031  0.023034  0.024037  0.021431   0.017757    0.755802       0.182980
# 10032  0.022481  0.023470  0.020942   0.020595    0.773106       0.169837
# 10033  0.021051  0.022675  0.020421   0.019311    0.731321       0.175561
# 10034  0.016222  0.013435  0.015472   0.013042    0.713938       0.200292
# 10040  0.016567  0.014409  0.015837   0.014903    0.725590       0.194354
# 11691  0.035363  0.017334  0.018489   0.021740    0.757806       0.172168
# 11692  0.010761  0.005141  0.006149   0.005680    0.742197       0.184971
# 11693  0.005568  0.003145  0.004748   0.004647    0.636842       0.233333
# 11694  0.008228  0.004620  0.008656   0.011729    0.496591       0.239773
# 11697  0.001579  0.000685  0.001447   0.002762    0.357843       0.269608
# 11204  0.043212  0.024863  0.027257   0.030735    0.733533       0.167665
# 11218  0.040534  0.026267  0.029084   0.024703    0.636748       0.212451
# 11219  0.064783  0.031196  0.026527   0.028926    0.814643       0.118826
# 11230  0.045512  0.027228  0.028330   0.036764    0.667138       0.195018
# 11201  0.014639  0.021969  0.021184   0.018350    0.333333       0.231392
# 11205  0.021162  0.017474  0.012070   0.008406    0.614362       0.226064
# 11215  0.021630  0.025523  0.027096   0.019435    0.364744       0.270809
# 11217  0.011434  0.014849  0.014742   0.010712    0.414911       0.268504
# 11231  0.012945  0.012228  0.014031   0.009755    0.435322       0.227998
# 11203  0.032555  0.021289  0.025891   0.031019    0.731792       0.207071
# 11210  0.033246  0.017876  0.020568   0.022105    0.661091       0.211777
# 11225  0.024606  0.018684  0.019587   0.018706    0.694172       0.230517
# 11226  0.047714  0.032172  0.034933   0.031532    0.761048       0.186340
# 11220  0.049234  0.040658  0.038968   0.030427    0.863092       0.097660
# 11232  0.012685  0.015058  0.012694   0.006881    0.746758       0.180015
#
#        high_income     shoes  restaurant       gym   clothes    clinic
# 10026     0.153261  0.000000    0.007101  0.000000  0.000000  0.014925
# 10027     0.133043  0.017857    0.009862  0.062500  0.010395  0.014925
# 10030     0.060825  0.000000    0.002367  0.015625  0.000000  0.000000
# 10037     0.096030  0.000000    0.000789  0.015625  0.000000  0.000000
# 10039     0.061856  0.000000    0.000000  0.000000  0.000000  0.000000
# 10001     0.338924  0.133929    0.031164  0.093750  0.081081  0.014925
# 10011     0.478878  0.026786    0.046548  0.062500  0.054054  0.044776
# 10018     0.387944  0.008929    0.020513  0.015625  0.016632  0.000000
# 10019     0.410865  0.017857    0.046943  0.015625  0.041580  0.014925
# 10036     0.347989  0.026786    0.038264  0.000000  0.035343  0.029851
# 10029     0.073907  0.008929    0.014596  0.015625  0.002079  0.029851
# 10035     0.083875  0.008929    0.005128  0.015625  0.000000  0.014925
# 10010     0.450801  0.017857    0.021696  0.062500  0.010395  0.089552
# 10016     0.418748  0.008929    0.047337  0.015625  0.006237  0.089552
# 10017     0.501629  0.062500    0.018935  0.015625  0.037422  0.014925
# 10022     0.528423  0.053571    0.019724  0.046875  0.049896  0.044776
# 10012     0.417574  0.116071    0.047732  0.015625  0.168399  0.000000
# 10013     0.383035  0.062500    0.042998  0.000000  0.047817  0.014925
# 10014     0.492412  0.008929    0.035503  0.015625  0.016632  0.014925
# 10004     0.562249  0.008929    0.015779  0.000000  0.004158  0.000000
# 10005     0.501623  0.000000    0.010651  0.015625  0.002079  0.000000
# 10006     0.489712  0.008929    0.006312  0.000000  0.000000  0.000000
# 10007     0.648649  0.008929    0.005917  0.000000  0.002079  0.014925
# 10038     0.326781  0.008929    0.024063  0.015625  0.022869  0.014925
# 10280     0.586207  0.000000    0.003550  0.000000  0.000000  0.000000
# 10002     0.119704  0.008929    0.035897  0.015625  0.020790  0.014925
# 10003     0.433611  0.080357    0.059961  0.078125  0.058212  0.059701
# 10009     0.213883  0.008929    0.021302  0.000000  0.002079  0.014925
# 10021     0.495037  0.017857    0.009073  0.000000  0.012474  0.000000
# 10028     0.457286  0.000000    0.012623  0.000000  0.018711  0.029851
# ...            ...       ...         ...       ...       ...       ...
# 10075     0.474012  0.000000    0.006706  0.000000  0.006237  0.014925
# 10128     0.422388  0.000000    0.023669  0.015625  0.002079  0.029851
# 10023     0.503519  0.026786    0.018935  0.031250  0.037422  0.029851
# 10024     0.478135  0.044643    0.031164  0.000000  0.016632  0.029851
# 10025     0.321780  0.008929    0.039448  0.000000  0.006237  0.044776
# 10031     0.061218  0.008929    0.005128  0.031250  0.000000  0.014925
# 10032     0.057057  0.000000    0.001972  0.015625  0.000000  0.000000
# 10033     0.093117  0.000000    0.007101  0.000000  0.000000  0.000000
# 10034     0.085770  0.000000    0.005917  0.000000  0.000000  0.000000
# 10040     0.080056  0.000000    0.002367  0.000000  0.000000  0.000000
# 11691     0.070027  0.000000    0.000789  0.000000  0.000000  0.000000
# 11692     0.072832  0.000000    0.000394  0.015625  0.000000  0.000000
# 11693     0.129825  0.008929    0.002367  0.000000  0.002079  0.000000
# 11694     0.263636  0.000000    0.000000  0.000000  0.000000  0.000000
# 11697     0.372549  0.000000    0.001183  0.000000  0.000000  0.000000
# 11204     0.098802  0.017857    0.003550  0.000000  0.006237  0.044776
# 11218     0.150801  0.000000    0.011440  0.000000  0.000000  0.000000
# 11219     0.066531  0.008929    0.003550  0.000000  0.006237  0.000000
# 11230     0.137843  0.000000    0.001972  0.000000  0.002079  0.000000
# 11201     0.435275  0.035714    0.034714  0.093750  0.056133  0.059701
# 11205     0.159574  0.000000    0.012229  0.000000  0.000000  0.014925
# 11215     0.364447  0.080357    0.043393  0.015625  0.060291  0.014925
# 11217     0.316586  0.008929    0.035897  0.093750  0.066528  0.000000
# 11231     0.336680  0.000000    0.016963  0.015625  0.002079  0.029851
# 11203     0.061138  0.000000    0.000789  0.015625  0.000000  0.014925
# 11210     0.127133  0.000000    0.000000  0.000000  0.000000  0.000000
# 11225     0.075311  0.000000    0.002367  0.000000  0.000000  0.000000
# 11226     0.052611  0.000000    0.005523  0.000000  0.002079  0.014925
# 11220     0.039248  0.008929    0.005917  0.015625  0.000000  0.029851
# 11232     0.073227  0.000000    0.002761  0.000000  0.000000  0.000000
#
# [62 rows x 12 columns]

# %%
def rank(df, age, wealth, product, top_n):
    df1 = df.copy()
    df1['score'] = (df[age] + df[wealth] + df[product]) / 3
    df2 = df1.sort_values('score', ascending=False)
    rank_list = df2.index.tolist()
    return rank_list[:top_n]

# %%
# Using example
r = rank(zip_wo, 'age19_35', 'high_income', 'shoes', 10)
r
# Out:
# [10007, 10022, 10280, 10004, 10017, 10023, 10012, 10003, 10024, 10021]

# %%
# python -c 'import filter; print(filter.filter("age19_35", "high_income", "shoes", 10))'
